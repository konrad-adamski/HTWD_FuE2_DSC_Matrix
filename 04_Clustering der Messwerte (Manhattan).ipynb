# %% [markdown]
# # Hierarchisches Clustering

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import StandardScaler

# %%
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
from scipy.cluster.hierarchy import linkage, fcluster

# %% [markdown]
# ## I) Für Gesamtverlauf (-25 bis 275°C)

# %%
file_path = "data/03_dsc_experiments_normalized.csv"

# %%
df_normalized = pd.read_csv(file_path, index_col=0)
df_normalized
# Out:
#               -24       -23       -22       -21       -20       -19       -18  \
# Probe
# L001_S5 -0.414724 -0.414344 -0.414483 -0.413907 -0.413091 -0.412114 -0.411125
# L002_S5 -0.435184 -0.434524 -0.434483 -0.433781 -0.432752 -0.431863 -0.431203
# L003_S5 -0.428877 -0.427999 -0.427776 -0.427276 -0.426766 -0.426015 -0.424954
# L004_S5 -0.421902 -0.421595 -0.421571 -0.420891 -0.420325 -0.420069 -0.419861
# L005_S5 -0.391589 -0.391113 -0.390807 -0.390103 -0.389683 -0.389155 -0.388540
# ...           ...       ...       ...       ...       ...       ...       ...
# L383_S5 -0.397226 -0.396507 -0.396912 -0.396228 -0.396026 -0.395692 -0.395082
# L384_S5 -0.359978 -0.359520 -0.359721 -0.359194 -0.358705 -0.358458 -0.358139
# L385_S5 -0.385729 -0.385336 -0.385706 -0.385314 -0.384946 -0.384705 -0.384093
# L386_S5 -0.361336 -0.360712 -0.360746 -0.360451 -0.360310 -0.360230 -0.359314
# L387_S5 -0.354584 -0.353460 -0.353536 -0.353527 -0.353294 -0.353122 -0.352732
#
#               -17       -16       -15  ...       265       266       267  \
# Probe                                  ...
# L001_S5 -0.410646 -0.410275 -0.409311  ... -0.266759 -0.266185 -0.265381
# L002_S5 -0.430658 -0.430484 -0.429743  ... -0.291320 -0.291141 -0.291032
# L003_S5 -0.424150 -0.423851 -0.422880  ... -0.278368 -0.277813 -0.277327
# L004_S5 -0.419415 -0.419352 -0.418570  ... -0.279800 -0.279349 -0.278981
# L005_S5 -0.388102 -0.388012 -0.387468  ... -0.250822 -0.249905 -0.248846
# ...           ...       ...       ...  ...       ...       ...       ...
# L383_S5 -0.394552 -0.394373 -0.393518  ... -0.200208 -0.199664 -0.198722
# L384_S5 -0.357822 -0.357564 -0.356888  ... -0.079416 -0.078088 -0.077201
# L385_S5 -0.383679 -0.383648 -0.383061  ... -0.183764 -0.183355 -0.182589
# L386_S5 -0.358913 -0.359387 -0.358647  ... -0.135015 -0.133994 -0.133478
# L387_S5 -0.352425 -0.352347 -0.351630  ... -0.104336 -0.103521 -0.102435
#
#               268       269       270       271       272       273       274
# Probe
# L001_S5 -0.264771 -0.264402 -0.263895 -0.263217 -0.262609 -0.261971 -0.261483
# L002_S5 -0.290187 -0.289162 -0.288294 -0.287320 -0.286521 -0.285654 -0.284781
# L003_S5 -0.276705 -0.276381 -0.275983 -0.275113 -0.274239 -0.273117 -0.272201
# L004_S5 -0.278759 -0.278387 -0.277662 -0.276952 -0.276491 -0.275677 -0.274862
# L005_S5 -0.247748 -0.246896 -0.246135 -0.245566 -0.245141 -0.244713 -0.244202
# ...           ...       ...       ...       ...       ...       ...       ...
# L383_S5 -0.198138 -0.197793 -0.197055 -0.196439 -0.195968 -0.195069 -0.194250
# L384_S5 -0.076134 -0.075794 -0.075150 -0.073460 -0.072286 -0.071478 -0.070959
# L385_S5 -0.181873 -0.181074 -0.180660 -0.179500 -0.178707 -0.177974 -0.178240
# L386_S5 -0.132486 -0.131302 -0.130898 -0.130300 -0.129430 -0.128833 -0.128022
# L387_S5 -0.102100 -0.101193 -0.100113 -0.098958 -0.098036 -0.097247 -0.095795
#
# [358 rows x 299 columns]

# %% [markdown]
# ### 4) Anwendung des Hierarchischen Clusterings

# %%
# Linkage-Matrix mit der Manhattan-Metrik erstellen
linked = linkage(df_normalized, method="average", metric="cityblock")

# %% [markdown]
# ### 5) Visualisierung

# %%
plt.figure(figsize=(12, 8))
dendrogram(
    linked,
    labels=df_normalized.index,  # Proben als Beschriftungen
    orientation="top",
    distance_sort="descending",
)
plt.title("Dendrogramm der S5-Proben")
plt.xlabel("Proben")
plt.ylabel("Distanz")
plt.show()

# %% [markdown]
# ### 6) Clusterzuordnung berechnen

# %% [markdown]
# #### a) Feste Anzahl an Clustern
# > 5 Cluster (da 5 Sedimente/Matritzen)

# %%
cluster_model = AgglomerativeClustering(
    n_clusters=5, 
    metric="manhattan", 
    linkage="average"  # Du kannst hier auch "single" oder "complete" wählen
)
cluster_labels = cluster_model.fit_predict(df_normalized)

# %%
# Cluster-Zuweisung als DataFrame
cluster_assignments = pd.DataFrame({
    "Probe": df_normalized.index,
    "Cluster": cluster_labels
})
cluster_assignments
# Out:
#        Probe  Cluster
# 0    L001_S5        2
# 1    L002_S5        2
# 2    L003_S5        2
# 3    L004_S5        2
# 4    L005_S5        2
# ..       ...      ...
# 353  L383_S5        2
# 354  L384_S5        2
# 355  L385_S5        2
# 356  L386_S5        2
# 357  L387_S5        2
#
# [358 rows x 2 columns]

# %%
cluster_assignments["Cluster"].value_counts()
# Out:
# Cluster
# 2    304
# 0     27
# 1     24
# 3      2
# 4      1
# Name: count, dtype: int64

# %%
cluster_assignments.to_csv("data/040a_simple_clustering.csv", index=True)

# %% [markdown]
# #### b) Basieren auf gegebenen Cutoff Point (Distanzschwelle)
# > aus Dendogramm

# %%
# Cluster mit einem bestimmten Cutoff-Distanzwert erzeugen
cutoff_distance = 200  # Beispiel für den Cutoff Point
clusters = fcluster(linked, t=cutoff_distance, criterion="distance")

# %%
# Cluster in DataFrame speichern
cluster_results = pd.DataFrame({
    "Probe": df_normalized.index,
    "Cluster": clusters.flatten()  # `cut_tree` gibt ein 2D-Array zurück
})
cluster_results
# Out:
#        Probe  Cluster
# 0    L001_S5        1
# 1    L002_S5        1
# 2    L003_S5        1
# 3    L004_S5        1
# 4    L005_S5        1
# ..       ...      ...
# 353  L383_S5        1
# 354  L384_S5        1
# 355  L385_S5        1
# 356  L386_S5        1
# 357  L387_S5        1
#
# [358 rows x 2 columns]

# %%
cluster_results["Cluster"].value_counts()
# Out:
# Cluster
# 1    304
# 6     24
# 3     17
# 4     10
# 5      2
# 2      1
# Name: count, dtype: int64

# %%
cluster_results.to_csv("data/040b_simple_clustering.csv", index=True)

# %% [markdown]
# ## II) Basierend auf Intervallen (Mittelwerten)
# > eine Cluster-Zuweisung für Gesamtverlauf

# %%
file_path = "data/03_dsc_experiments_normalized_intervals.csv"

df_normalized = pd.read_csv(file_path, index_col=0)
df_normalized
# Out:
#          [-25, -5)  [-5, 15)  [15, 35)  [35, 55)  [55, 75)  [75, 95)  \
# Probe
# L001_S5  -0.409775 -0.400449 -0.389641 -0.380218 -0.369950 -0.361466
# L002_S5  -0.430105 -0.420957 -0.411449 -0.401776 -0.391775 -0.383122
# L003_S5  -0.423493 -0.414713 -0.405592 -0.395556 -0.386346 -0.378948
# L004_S5  -0.418961 -0.414369 -0.406470 -0.397428 -0.389731 -0.383091
# L005_S5  -0.387591 -0.382980 -0.373814 -0.362412 -0.351413 -0.341765
# ...            ...       ...       ...       ...       ...       ...
# L383_S5  -0.393431 -0.383219 -0.373145 -0.362479 -0.351026 -0.338704
# L384_S5  -0.356280 -0.344942 -0.330514 -0.315836 -0.300962 -0.285687
# L385_S5  -0.382964 -0.373991 -0.363618 -0.352263 -0.338732 -0.325401
# L386_S5  -0.358295 -0.349373 -0.339012 -0.327963 -0.313954 -0.299963
# L387_S5  -0.351123 -0.340804 -0.329452 -0.316827 -0.301988 -0.287027
#
#          [95, 115)  [115, 135)  [135, 155)  [155, 175)  [175, 195)  \
# Probe
# L001_S5  -0.350984   -0.326757   -0.340201   -0.328247   -0.314883
# L002_S5  -0.372093   -0.346959   -0.358927   -0.347063   -0.333821
# L003_S5  -0.368215   -0.340201   -0.356403   -0.344092   -0.329523
# L004_S5  -0.372984   -0.348708   -0.358773   -0.346115   -0.330911
# L005_S5  -0.330902   -0.313030   -0.317008   -0.305931   -0.292917
# ...            ...         ...         ...         ...         ...
# L383_S5  -0.329780   -0.334494   -0.291703   -0.276513   -0.259814
# L384_S5  -0.275729   -0.293425   -0.220209   -0.198126   -0.173821
# L385_S5  -0.314765   -0.317284   -0.274411   -0.258304   -0.241273
# L386_S5  -0.290021   -0.300889   -0.243587   -0.225423   -0.206089
# L387_S5  -0.275868   -0.289480   -0.223963   -0.204022   -0.182555
#
#          [195, 215)  [215, 235)  [235, 255)  [255, 275)
# Probe
# L001_S5   -0.303720   -0.291783   -0.279244   -0.266946
# L002_S5   -0.323707   -0.313462   -0.302590   -0.291381
# L003_S5   -0.317811   -0.305474   -0.292270   -0.279037
# L004_S5   -0.317903   -0.304724   -0.292959   -0.280454
# L005_S5   -0.282687   -0.271345   -0.260785   -0.249944
# ...             ...         ...         ...         ...
# L383_S5   -0.243557   -0.227633   -0.213402   -0.200450
# L384_S5   -0.150114   -0.125819   -0.099549   -0.079439
# L385_S5   -0.225589   -0.211926   -0.197541   -0.184160
# L386_S5   -0.187279   -0.169649   -0.151571   -0.135253
# L387_S5   -0.162013   -0.142649   -0.123195   -0.104925
#
# [358 rows x 15 columns]

# %% [markdown]
# ### 2) Anwendung des Hierarchischen Clusterings

# %%
#Linkage-Matrix mit der Manhattan-Metrik erstellen
linked = linkage(df_normalized, method="average", metric="cityblock")  # "cityblock" = Manhattan

# %%
plt.figure(figsize=(12, 8))
dendrogram(
    linked,
    labels=df_normalized.index,  # Proben als Beschriftungen
    orientation="top",
    distance_sort="descending",
)
plt.title("Dendrogramm der S5-Proben")
plt.xlabel("Proben")
plt.ylabel("Distanz")
plt.show()

# %% [markdown]
# ### 3) Clusterzuordnung berechnen

# %% [markdown]
# #### a) Feste Anzahl an Clustern
# > 5 Cluster (da 5 Sedimente/Matritzen)

# %%
cluster_model = AgglomerativeClustering(n_clusters=5, metric="euclidean", linkage="ward")
cluster_labels = cluster_model.fit_predict(df_normalized)

# Cluster-Zuweisung als DataFrame
cluster_assignments = pd.DataFrame({
    "Probe": df_normalized.index,
    "Cluster": cluster_labels
})
cluster_assignments
# Out:
#        Probe  Cluster
# 0    L001_S5        3
# 1    L002_S5        3
# 2    L003_S5        3
# 3    L004_S5        3
# 4    L005_S5        3
# ..       ...      ...
# 353  L383_S5        3
# 354  L384_S5        3
# 355  L385_S5        3
# 356  L386_S5        3
# 357  L387_S5        3
#
# [358 rows x 2 columns]

# %%
cluster_assignments["Cluster"].value_counts()
# Out:
# Cluster
# 3    305
# 0     15
# 1     14
# 4     14
# 2     10
# Name: count, dtype: int64

# %%
cluster_assignments.to_csv("data/041a_mean_clustering.csv", index=True)

# %% [markdown]
# #### b) Basieren auf gegebenen Cutoff Point (Distanzschwelle)
# > aus Dendogramm

# %%
cutoff_distance = 8  # Beispiel für den Cutoff Point
clusters = fcluster(linked, t=cutoff_distance, criterion="distance")


# Cluster in DataFrame speichern
cluster_results = pd.DataFrame({
    "Probe": df_normalized.index,
    "Cluster": clusters.flatten()  # `cut_tree` gibt ein 2D-Array zurück
})
cluster_results
# Out:
#        Probe  Cluster
# 0    L001_S5        1
# 1    L002_S5        1
# 2    L003_S5        1
# 3    L004_S5        1
# 4    L005_S5        1
# ..       ...      ...
# 353  L383_S5        1
# 354  L384_S5        1
# 355  L385_S5        1
# 356  L386_S5        1
# 357  L387_S5        1
#
# [358 rows x 2 columns]

# %%
cluster_results["Cluster"].value_counts()
# Out:
# Cluster
# 1    304
# 3     17
# 6     13
# 7     11
# 4     10
# 5      2
# 2      1
# Name: count, dtype: int64

# %%
cluster_results.to_csv("data/041b_mean_clustering.csv", index=True)

# %% [markdown]
# ## III) Basierend auf Intervallen (Mittelwerten)
# > Pro Interval eine Cluster-Zuweisung

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# Iteriere über jede Spalte (Intervall)
for column in df_normalized.columns:
    # Berechnung der Linkage-Matrix
    linked = linkage(df_normalized[[column]], method="average", metric="cityblock")
    
    # Dendrogramm plotten
    plt.figure(figsize=(10, 6))
    dendrogram(linked, orientation="top", distance_sort="descending", labels=df_normalized.index)
    plt.title(f"Dendrogramm für Intervall: {column}")
    plt.xlabel("Proben")
    plt.ylabel("Distanz")
    plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import pandas as pd

# DataFrame für Cluster-Zuweisungen initialisieren
cluster_results = pd.DataFrame(index=df_normalized.index)

# Iteriere über jede Spalte (Intervall)
for column in df_normalized.columns:
    
    # Hierarchisches Clustering für die aktuelle Spalte
    cluster_model = AgglomerativeClustering(
        n_clusters=8, 
        metric="manhattan", 
        linkage="average"  # Du kannst hier auch "single" oder "complete" wählen
    )
    cluster_labels = cluster_model.fit_predict(df_normalized[[column]])
    
    # Speichere die Cluster-Zuweisung in den Ergebnissen
    cluster_results[column] = cluster_labels

# Ergebnisse anzeigen
cluster_results
# Out:
#          [-25, -5)  [-5, 15)  [15, 35)  [35, 55)  [55, 75)  [75, 95)  \
# Probe
# L001_S5          1         1         4         4         4         2
# L002_S5          1         1         4         4         4         2
# L003_S5          1         1         4         4         4         2
# L004_S5          1         1         4         4         4         2
# L005_S5          1         1         4         4         4         2
# ...            ...       ...       ...       ...       ...       ...
# L383_S5          1         1         4         4         4         2
# L384_S5          1         1         4         4         4         2
# L385_S5          1         1         4         4         4         2
# L386_S5          1         1         4         4         4         2
# L387_S5          1         1         4         4         4         2
#
#          [95, 115)  [115, 135)  [135, 155)  [155, 175)  [175, 195)  \
# Probe
# L001_S5          2           1           2           1           5
# L002_S5          2           1           2           1           5
# L003_S5          2           1           2           1           5
# L004_S5          2           1           2           1           5
# L005_S5          2           1           2           1           5
# ...            ...         ...         ...         ...         ...
# L383_S5          2           1           2           1           5
# L384_S5          2           1           2           1           5
# L385_S5          2           1           2           1           5
# L386_S5          2           1           2           1           5
# L387_S5          2           1           2           1           5
#
#          [195, 215)  [215, 235)  [235, 255)  [255, 275)
# Probe
# L001_S5           2           5           0           2
# L002_S5           2           5           0           2
# L003_S5           2           5           0           2
# L004_S5           2           5           0           2
# L005_S5           2           5           0           2
# ...             ...         ...         ...         ...
# L383_S5           2           5           0           2
# L384_S5           2           5           0           2
# L385_S5           2           5           0           2
# L386_S5           2           5           0           2
# L387_S5           2           5           0           2
#
# [358 rows x 15 columns]

# %%
# DataFrame für Häufigkeiten initialisieren
cluster_value_counts = {}

# Iteriere über jede Spalte (Intervall)
for column in cluster_results.columns:
    # Berechne die Häufigkeit der Cluster-Zuweisungen
    value_counts = cluster_results[column].value_counts()
    
    # Speichere die Ergebnisse in einem Dictionary
    cluster_value_counts[column] = value_counts

# Konvertiere das Dictionary in einen DataFrame für bessere Übersicht
cluster_counts_df = pd.DataFrame(cluster_value_counts).fillna(0).astype(int)

# Ergebnisse anzeigen
cluster_counts_df
# Out:
#    [-25, -5)  [-5, 15)  [15, 35)  [35, 55)  [55, 75)  [75, 95)  [95, 115)  \
# 0         22        18        20        19        21        20         10
# 1        303       303         2         2         2         2         10
# 2         12        11        11        12         6       304        304
# 3          6         4        13        13        13         7         18
# 4          2         3       303       303       303         1          1
# 5          3         2         3         3        11         6          6
# 6          9        16         5         5         1         9          8
# 7          1         1         1         1         1         9          1
#
#    [115, 135)  [135, 155)  [155, 175)  [175, 195)  [195, 215)  [215, 235)  \
# 0          17          19          17          17          17          17
# 1         304          12         304           4           4           4
# 2          13         304          10          18         304          17
# 3           2           5           6           2           2           6
# 4          11           1           2           1           1           1
# 5           9           5           4         304          17         304
# 6           1          10          14           6           7           7
# 7           1           2           1           6           6           2
#
#    [235, 255)  [255, 275)
# 0         305           9
# 1          18          13
# 2           8         305
# 3           8           8
# 4           1           1
# 5           9          12
# 6           7           8
# 7           2           2

# %% [markdown]
# ### übergeordnetes Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# Linkage-Matrix für hierarchisches Clustering auf allen Intervallen
linked = linkage(df_normalized, method="average", metric="cityblock")  # "cityblock" = Manhattan

# Dendrogramm plotten
plt.figure(figsize=(12, 8))
dendrogram(
    linked,
    labels=cluster_results.index,  # Proben als Beschriftung
    orientation="top",
    distance_sort="descending"
)
plt.title("Dendrogramm für alle Intervalle (Gesamthierarchie)")
plt.xlabel("Proben")
plt.ylabel("Distanz")
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import pandas as pd

# Konvertiere die Spaltennamen zu Strings
cluster_results.columns = cluster_results.columns.astype(str)

# Hierarchisches Clustering auf Basis aller Spalten (Intervalle)
cluster_model = AgglomerativeClustering(
    n_clusters=6, 
    metric="manhattan", 
    linkage="average"  # Du kannst hier auch "single" oder "complete" wählen
)
overall_clusters = cluster_model.fit_predict(cluster_results.values)  # Nutze nur die Werte

# Ergebnisse als neue Spalte hinzufügen
cluster_results["Overall_Cluster"] = overall_clusters

# Ausgabe der Ergebnisse
cluster_results
# Out:
#          [-25, -5)  [-5, 15)  [15, 35)  [35, 55)  [55, 75)  [75, 95)  \
# Probe
# L001_S5          1         1         4         4         4         2
# L002_S5          1         1         4         4         4         2
# L003_S5          1         1         4         4         4         2
# L004_S5          1         1         4         4         4         2
# L005_S5          1         1         4         4         4         2
# ...            ...       ...       ...       ...       ...       ...
# L383_S5          1         1         4         4         4         2
# L384_S5          1         1         4         4         4         2
# L385_S5          1         1         4         4         4         2
# L386_S5          1         1         4         4         4         2
# L387_S5          1         1         4         4         4         2
#
#          [95, 115)  [115, 135)  [135, 155)  [155, 175)  [175, 195)  \
# Probe
# L001_S5          2           1           2           1           5
# L002_S5          2           1           2           1           5
# L003_S5          2           1           2           1           5
# L004_S5          2           1           2           1           5
# L005_S5          2           1           2           1           5
# ...            ...         ...         ...         ...         ...
# L383_S5          2           1           2           1           5
# L384_S5          2           1           2           1           5
# L385_S5          2           1           2           1           5
# L386_S5          2           1           2           1           5
# L387_S5          2           1           2           1           5
#
#          [195, 215)  [215, 235)  [235, 255)  [255, 275)  Overall_Cluster
# Probe
# L001_S5           2           5           0           2                1
# L002_S5           2           5           0           2                1
# L003_S5           2           5           0           2                1
# L004_S5           2           5           0           2                1
# L005_S5           2           5           0           2                1
# ...             ...         ...         ...         ...              ...
# L383_S5           2           5           0           2                1
# L384_S5           2           5           0           2                1
# L385_S5           2           5           0           2                1
# L386_S5           2           5           0           2                1
# L387_S5           2           5           0           2                1
#
# [358 rows x 16 columns]

# %%
# Häufigkeiten der Cluster-Zuweisungen berechnen
cluster_counts = cluster_results["Overall_Cluster"].value_counts()
cluster_counts.sort_index()
# Out:
# Overall_Cluster
# 0      7
# 1    327
# 2     17
# 3      2
# 4      1
# 5      4
# Name: count, dtype: int64

# %%
cluster_results.to_csv("data/042_interval_multiple_clustering.csv", index=True)
